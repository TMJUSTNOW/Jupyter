# %% [markdown]
# ## Retail Project

# %%
# Gemeral
import numpy as np
import pandas as pd
import nltk
import random
import os

# Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS
#from ggplot import *

# Pre-Processing
import string
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer

#Performance
# %load_ext memory_profiler

# Extra
from os import path
from PIL import Image

# Model = np.array(Image.open("model.png"))
# Failed attempted at adding a form to wordcloud

# %%
# Read
os.chdir(r"C:\Users\Nicol\Google Drive\Learning\Jupyter\NLP\Retail Project")
os.listdir()

data = pd.ExcelFile("retail dataset.xlsx")
df = data.parse("Sheet1", header=1)
df = df.drop(["Unnamed: 18", "Unnamed: 19", "Unnamed: 20", "Unnamed: 21","Unnamed: 22","Unnamed: 23","Unnamed: 24","Unnamed: 25","Unnamed: 26"], axis = 1)
df = df.drop(["REVIEW_ID", "RATING_RANGE"], axis = 1)

df["LABEL"] = 0
df.loc[df.RATING >= 3,"LABEL"] = 1

# %%
print(df.head())
df.info()
# Out:
#   STERLINGEXTERNALALIAS  AGE              IID                    TITLE  \
# 0              40175747   33  100008000000000                      NaN
# 1         4130200000000   34  100000000000000                      NaN
# 2         4130080000000   60  100000000000000  Some major design flaws
# 3         4123200000000   50  100001000000000         My Favorite Buy!
# 4         4110530000000   47  100001000000000         Flattering shirt
#
#                                          REVIEW_TEXT  RATING  RECOMMENDED_IND  \
# 0  absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  It's sooo pretty.  I happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. It's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    NUM_FEEDBACKS  NUM_POSITIVE_FEEDBACKS  NUM_NEGATIVE_FEEDBACKS  DIVISION_ID  \
# 0              0                       0                       0         42.0
# 1              4                       4                       0         41.0
# 2              0                       0                       0         41.0
# 3              0                       0                       0         49.0
# 4              6                       6                       0         41.0
#
#                    DIVISION_NAME  DEPARTMENT_ID  \
# 0         ANTHRO  INTIMATES (NA)          414.0
# 1  ANTHRO. WOMEN'S DIVISION (NA)          413.0
# 2  ANTHRO. WOMEN'S DIVISION (NA)          413.0
# 3    ANTHRO. MISC. DIVISION (NA)          492.0
# 4  ANTHRO. WOMEN'S DIVISION (NA)          411.0
#
#                  DEPARTMENT_NAME  CLASS_ID               CLASS_NAME  LABEL
# 0  ANTHRO. WOMEN'S INTIMATE (NA)    4140.0  INTIMATES - ANTHRO (NA)      1
# 1     ANTHRO. WOMEN'S OTHER (NA)    4130.0   DRESSES - ANTHRO. (NA)      1
# 2     ANTHRO. WOMEN'S OTHER (NA)    4130.0   DRESSES - ANTHRO. (NA)      1
# 3                   PETITES (NA)    4927.0     PANTS - PETITES (NA)      1
# 4      ANTHRO. WOMEN'S TOPS (NA)    4110.0   BLOUSES - ANTHRO. (NA)      1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 17 columns):
# STERLINGEXTERNALALIAS     23486 non-null object
# AGE                       23486 non-null int64
# IID                       23486 non-null int64
# TITLE                     19676 non-null object
# REVIEW_TEXT               22641 non-null object
# RATING                    23486 non-null int64
# RECOMMENDED_IND           23486 non-null int64
# NUM_FEEDBACKS             23486 non-null int64
# NUM_POSITIVE_FEEDBACKS    23486 non-null int64
# NUM_NEGATIVE_FEEDBACKS    23486 non-null int64
# DIVISION_ID               23472 non-null float64
# DIVISION_NAME             23472 non-null object
# DEPARTMENT_ID             23472 non-null float64
# DEPARTMENT_NAME           23472 non-null object
# CLASS_ID                  23472 non-null float64
# CLASS_NAME                23472 non-null object
# LABEL                     23486 non-null int64
# dtypes: float64(3), int64(8), object(6)
# memory usage: 3.0+ MB

# %% [markdown]
# ## PreProcessing

# %%
ps = PorterStemmer()
tokenizer = RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))

def preprocessing(data):
    txt = data.str.lower().str.cat(sep=' ')
    words = tokenizer.tokenize(txt)
    words = [w for w in words if not w in stop_words]
    #words = [ps.stem(w) for w in words] #Stemmed version
    return words

# %% [markdown]
# ## Functions

# %%
def wordfreqviz(text, x):
    word_dist = nltk.FreqDist(text)
    top_N = x
    rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
    matplotlib.style.use('ggplot')
    rslt.plot.bar(rot=0)

def wordfreq(text, x):
    word_dist = nltk.FreqDist(text)
    top_N = x
    rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
    print(rslt)
    
# https://www.kaggle.com/longdoan/word-cloud-with-python
# https://github.com/amueller/word_cloud/issues/134
# https://amueller.github.io/word_cloud/auto_examples/masked.html

def cloud(text):
    mpl.rcParams['figure.figsize']=(10.0,10.0)    #(6.0,4.0)
    mpl.rcParams['font.size']=12                #10 
    mpl.rcParams['savefig.dpi']=100             #72 
    mpl.rcParams['figure.subplot.bottom']=.1 

    stopwords = set(STOPWORDS) # Redundant
    
    wordcloud = WordCloud(width=1600, height=800,
                          background_color='black',
                          stopwords=stopwords,
                         ).generate(str(text))

    print(wordcloud)

    fig = plt.figure(figsize=(20,10), facecolor='k')
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()
    #fig.savefig("word1.png", dpi=900)

# %% [markdown]
# ## General Analysis

# %%
print(pd.crosstab(df['RATING'], df['CLASS_NAME']))
print(df[['CLASS_NAME', 'LABEL']].groupby(['CLASS_NAME'], as_index=False).mean())
# Out:
# CLASS_NAME  BLOUSES - ANTHRO. (NA)  BLOUSES - PETITES (NA)  \
# RATING
# 1                               74                      45
# 2                              155                      74
# 3                              254                     140
# 4                              441                     228
# 5                             1069                     617
#
# CLASS_NAME  CASUAL BOTTOMS (NA)  CHEMISES (NA)  CUT AND SEW KNITS-ANTHRO (NA)  \
# RATING
# 1                             0              0                            128
# 2                             0              0                            220
# 3                             0              0                            433
# 4                             1              1                            768
# 5                             1              0                           1710
#
# CLASS_NAME  DRESSES - ANTHRO. (NA)  DRESSES - PETITES (NA)  \
# RATING
# 1                              122                     106
# 2                              262                     199
# 3                              525                     313
# 4                              798                     597
# 5                             2023                    1374
#
# CLASS_NAME  FINE GAUGE - PETITES (NA)  FINE GAUGE-ANTHRO (NA)  \
# RATING
# 1                                  12                      18
# 2                                  14                      61
# 3                                  51                      68
# 4                                  85                     145
# 5                                 253                     393
#
# CLASS_NAME  INTIMATES - ANTHRO (NA)         ...           \
# RATING                                      ...
# 1                                 7         ...
# 2                                 8         ...
# 3                                16         ...
# 4                                27         ...
# 5                                96         ...
#
# CLASS_NAME  PANTS - PETITES (NA)  SHORTS - ANTHRO. (NA)  \
# RATING
# 1                             16                      9
# 2                             29                     17
# 3                             59                     41
# 4                            104                     67
# 5                            345                    183
#
# CLASS_NAME  SKIRTS - ANTHRO. (NA)  SKIRTS - PETITES (NA)  SLEEP (NA)  \
# RATING
# 1                              20                     14          10
# 2                              37                     14          15
# 3                              71                     37          17
# 4                             129                     79          44
# 5                             344                    200         142
#
# CLASS_NAME  SWEATERS - ANTHRO. (NA)  SWEATERS - PETITES (NA)  SWIM (NA)  \
# RATING
# 1                                33                       16         10
# 2                                70                       36         28
# 3                               124                       71         42
# 4                               178                       90         73
# 5                               495                      315        197
#
# CLASS_NAME  TREND (NA)  TREND - PETITE (NA)
# RATING
# 1                    9                    2
# 2                   10                    1
# 3                   13                    6
# 4                   21                    5
# 5                   43                    9
#
# [5 rows x 32 columns]
#                        CLASS_NAME     LABEL
# 0          BLOUSES - ANTHRO. (NA)  0.885098
# 1          BLOUSES - PETITES (NA)  0.892210
# 2             CASUAL BOTTOMS (NA)  1.000000
# 3                   CHEMISES (NA)  1.000000
# 4   CUT AND SEW KNITS-ANTHRO (NA)  0.893219
# 5          DRESSES - ANTHRO. (NA)  0.897051
# 6          DRESSES - PETITES (NA)  0.882194
# 7       FINE GAUGE - PETITES (NA)  0.937349
# 8          FINE GAUGE-ANTHRO (NA)  0.884672
# 9         INTIMATES - ANTHRO (NA)  0.902597
# 10         JACKETS - PETITES (NA)  0.902280
# 11           JACKETS-ANTHRO. (NA)  0.891688
# 12                     JEANS (NA)  0.923761
# 13           JEANS - PETITES (NA)  0.930556
# 14           KNITS - PETITES (NA)  0.900253
# 15                  LAYERING (NA)  0.924658
# 16                   LEGWEAR (NA)  0.903030
# 17                    LOUNGE (NA)  0.943231
# 18          LOUNGE - PETITES (NA)  0.905579
# 19       OUTERWEAR - ANTHRO. (NA)  0.903226
# 20       OUTERWEAR - PETITES (NA)  0.850000
# 21                     PANTS (NA)  0.905389
# 22           PANTS - PETITES (NA)  0.918626
# 23          SHORTS - ANTHRO. (NA)  0.917981
# 24          SKIRTS - ANTHRO. (NA)  0.905158
# 25          SKIRTS - PETITES (NA)  0.918605
# 26                     SLEEP (NA)  0.890351
# 27        SWEATERS - ANTHRO. (NA)  0.885556
# 28        SWEATERS - PETITES (NA)  0.901515
# 29                      SWIM (NA)  0.891429
# 30                     TREND (NA)  0.802083
# 31            TREND - PETITE (NA)  0.869565

# %%
print(pd.crosstab(df['RATING'], df['DEPARTMENT_NAME']))
print(df[['DEPARTMENT_NAME', 'LABEL']].groupby(['DEPARTMENT_NAME'], as_index=False).mean())
# Out:
# DEPARTMENT_NAME  ANTHRO WOMEN'S TREND (NA)  ANTHRO. WOMEN'S BOTTOMS (NA)  \
# RATING
# 1                                        9                            75
# 2                                       10                           147
# 3                                       13                           296
# 4                                       21                           526
# 5                                       43                          1498
#
# DEPARTMENT_NAME  ANTHRO. WOMEN'S INTIMATE (NA)  ANTHRO. WOMEN'S OTHER (NA)  \
# RATING
# 1                                           54                         122
# 2                                           77                         262
# 3                                          155                         525
# 4                                          315                         798
# 5                                          901                        2023
#
# DEPARTMENT_NAME  ANTHRO. WOMEN'S TOPS (NA)  JACKETS (NA)  PETITES (NA)
# RATING
# 1                                      253            32           297
# 2                                      506            35           528
# 3                                      879            60           943
# 4                                     1532           137          1748
# 5                                     3667           381          4604
#                  DEPARTMENT_NAME     LABEL
# 0      ANTHRO WOMEN'S TREND (NA)  0.802083
# 1   ANTHRO. WOMEN'S BOTTOMS (NA)  0.912667
# 2  ANTHRO. WOMEN'S INTIMATE (NA)  0.912783
# 3     ANTHRO. WOMEN'S OTHER (NA)  0.897051
# 4      ANTHRO. WOMEN'S TOPS (NA)  0.888986
# 5                   JACKETS (NA)  0.896124
# 6                   PETITES (NA)  0.898399

# %% [markdown]
# ## Sentiment Analysis

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment.util import *
import matplotlib.pyplot as plt
# Out:
# D:\WindowsApps\Anaconda\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
data = df[["TITLE","REVIEW_TEXT","CLASS_NAME","AGE","RATING", "LABEL"]]
SIA = SentimentIntensityAnalyzer()
data.REVIEW_TEXT= data.REVIEW_TEXT.astype(str)
# Out:
# D:\WindowsApps\Anaconda\lib\site-packages\pandas\core\generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
data['polarity_score']=data.REVIEW_TEXT.apply(lambda x:SIA.polarity_scores(x)['compound'])
data['neutral_score']=data.REVIEW_TEXT.apply(lambda x:SIA.polarity_scores(x)['neu'])
data['negative_score']=data.REVIEW_TEXT.apply(lambda x:SIA.polarity_scores(x)['neg'])
data['positive_score']=data.REVIEW_TEXT.apply(lambda x:SIA.polarity_scores(x)['pos'])
data['sentiment']=''
data.loc[data.polarity_score>0,'sentiment']='POSITIVE'
data.loc[data.polarity_score==0,'sentiment']='NEUTRAL'
data.loc[data.polarity_score<0,'sentiment']='NEGATIVE'
# Out:
# D:\WindowsApps\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# D:\WindowsApps\Anaconda\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# D:\WindowsApps\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# D:\WindowsApps\Anaconda\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\WindowsApps\Anaconda\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\WindowsApps\Anaconda\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
print(data[data.sentiment == "POSITIVE"][:5])
print(data[data.sentiment == "NEGATIVE"][:5])
# Out:
#                      TITLE                                        REVIEW_TEXT  \
# 0                      NaN  absolutely wonderful - silky and sexy and comf...
# 1                      NaN  Love this dress!  It's sooo pretty.  I happene...
# 2  Some major design flaws  I had such high hopes for this dress and reall...
# 3         My Favorite Buy!  I love, love, love this jumpsuit. It's fun, fl...
# 4         Flattering shirt  This shirt is very flattering to all due to th...
#
#                 CLASS_NAME  AGE  RATING  LABEL  polarity_score  neutral_score  \
# 0  INTIMATES - ANTHRO (NA)   33       4      1          0.8932          0.272
# 1   DRESSES - ANTHRO. (NA)   34       5      1          0.9729          0.664
# 2   DRESSES - ANTHRO. (NA)   60       3      1          0.9520          0.784
# 3     PANTS - PETITES (NA)   50       5      1          0.5727          0.340
# 4   BLOUSES - ANTHRO. (NA)   47       5      1          0.9291          0.700
#
#    negative_score  positive_score sentiment  \
# 0           0.000           0.728  POSITIVE
# 1           0.000           0.336  POSITIVE
# 2           0.027           0.190  POSITIVE
# 3           0.226           0.434  POSITIVE
# 4           0.000           0.300  POSITIVE
#
#                                            tokenized
# 0  [absolutely, wonderful, silky, sexy, comfortable]
# 1  [love, dress, sooo, pretty, happened, find, st...
# 2  [high, hopes, dress, really, wanted, work, ini...
# 3  [love, love, love, jumpsuit, fun, flirty, fabu...
# 4  [shirt, flattering, due, adjustable, front, ti...
#                                    TITLE  \
# 7   SHimmer, surprisingly goes with lots
# 9                      Such a fun dress!
# 61                            Itchy tags
# 77                          Zipper Broke
# 88                                  huge
#
#                                           REVIEW_TEXT  \
# 7   I ordered this in carbon for store pick up, an...
# 9   I'm 5"5' and 125 lbs. I ordered the S petite t...
# 61  3 tags sewn in, 2 small (about 1'' long) and 1...
# 77  The zipper broke on this piece the first time ...
# 88  really cute piece, but it's huge. i ordered an...
#
#                  CLASS_NAME  AGE  RATING  LABEL  polarity_score  \
# 7      KNITS - PETITES (NA)   39       4      1         -0.0909
# 9    DRESSES - ANTHRO. (NA)   34       5      1         -0.3724
# 61  INTIMATES - ANTHRO (NA)   36       1      0         -0.3002
# 77   BLOUSES - PETITES (NA)   28       2      0         -0.4879
# 88   BLOUSES - PETITES (NA)   38       2      0         -0.1145
#
#     neutral_score  negative_score  positive_score sentiment  \
# 7           0.901           0.046           0.053  NEGATIVE
# 9           0.753           0.120           0.126  NEGATIVE
# 61          0.734           0.148           0.118  NEGATIVE
# 77          0.724           0.174           0.102  NEGATIVE
# 88          0.601           0.208           0.191  NEGATIVE
#
#                                             tokenized
# 7   [ordered, carbon, store, pick, ton, stuff, alw...
# 9   [5, 5, 125, lbs, ordered, petite, make, sure, ...
# 61  [3, tags, sewn, 2, small, 1, long, 1, huge, 2,...
# 77  [zipper, broke, piece, first, time, wore, disa...
# 88  [really, cute, piece, huge, ordered, xxs, peti...

# %%
data.sentiment.value_counts().plot(kind='bar',title="sentiment analysis")
plt.show()

# %%
# Plot raiting distribtution

# %% [markdown]
# ## Simple Viz

# %%
df[["LABEL","RATING"]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026EABBCE2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026EABBA9B00>]], dtype=object)

# %% [markdown]
# ## Word Distribution and Word Cloud

# %%
# Highly Raited
out = preprocessing(df[df.RATING >= 3]['REVIEW_TEXT'])
#print(wordfreq(out,20))
print(cloud(out))
#print(wordfreqviz(out,10))
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000026EABB7C2B0>
# None

# %%
# Low Raited
out = preprocessing(df[df.RATING == 3]['REVIEW_TEXT'])
#print(wordfreq(out,20))
print(cloud(out))
#print(wordfreqviz(out,10))
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x0000026EABB61CC0>
# None

# %% [markdown]
# ## N Grams

# %%
from nltk.util import ngrams
from collections import Counter

def get_ngrams(text, n):
    n_grams = ngrams((text), n)
    return [ ' '.join(grams) for grams in n_grams]

def gramfreq(text,n,num):
    # Extracting bigrams
    result = get_ngrams(text,n)
    # Counting bigrams
    result_count = Counter(result)
    # Converting to the result to a data frame
    df = pd.DataFrame.from_dict(result_count, orient='index')
    df = df.rename(columns={'index':'words', 0:'frequency'}) # Renaming index column name
    #----output----
    print(df.sort_values(["frequency"],ascending=[0])[:num])

# %%
print(gramfreq(preprocessing(df[df.RATING < 3]['REVIEW_TEXT']),2,10))
print(gramfreq(preprocessing(df[df.RATING < 3]['REVIEW_TEXT']),3,10))
# Out:
#                frequency
# going back           144
# looked like          133
# wanted love          123
# looks like           117
# really wanted         81
# made look             78
# look like             75
# felt like             68
# 5 4                   66
# usually wear          66
# None
#                      frequency
# really wanted love          40
# really wanted like          28
# wanted love dress           24
# made look like              18
# fit true size               17
# way much fabric             16
# ordered usual size          16
# usually wear size           16
# sadly going back            16
# looked like wearing         14
# None

# %%
print(gramfreq(preprocessing(df[df.RATING > 3]['REVIEW_TEXT']),2,10))
print(gramfreq(preprocessing(df[df.RATING > 3]['REVIEW_TEXT']),3,10))
# Out:
#                 frequency
# true size            1203
# love dress            636
# 5 4                   585
# looks great           573
# usually wear          552
# fit perfectly         534
# love top              508
# well made             493
# fits perfectly        474
# 5 3                   466
# None
#                            frequency
# fits true size                   260
# fit true size                    186
# received many compliments        162
# love love love                   136
# runs true size                   136
# usually wear size                105
# every time wear                   80
# ordered usual size                76
# small fit perfectly               71
# got many compliments              70
# None

# %%
#gramfreq(preprocessing(df[([df.RATING] > 3) & ([df.RATING] < 3)]['REVIEW_TEXT']),2,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-d1e8394fe821> in <module>()
# ----> 1 gramfreq(preprocessing(df[([df.RATING] > 3) & ([df.RATING] < 3)]['REVIEW_TEXT']),2,30)
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
#preprocessing(df[([df.RATING] > 3) & ([df.RATING] < 3)][:4])

# %% [markdown]
# ## Supervised Learning

# %%
data['tokenized'] = data.REVIEW_TEXT.astype(str).str.lower() # turn into lower case text
data['tokenized'] = data.apply(lambda row: tokenizer.tokenize(row['tokenized']), axis=1) # apply tokenize to each row
data['tokenized'] = data['tokenized'].apply(lambda x: [w for w in x if not w in stop_words]) # remove stopwords from each row
#data['stemmed'] = data['tokenized'].apply(lambda x: [ps.stem(w) for w in x]) # apply stemming to each row
all_words = nltk.FreqDist(preprocessing(df['REVIEW_TEXT'])) # calculate word occurence from whole block of text
word_features= list(all_words.keys())[:3000] # 5000 most recurring unique words
# Out:
# D:\WindowsApps\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# D:\WindowsApps\Anaconda\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# D:\WindowsApps\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
labtext= list(zip(data.tokenized, (data.LABEL))) 
# Tuple each review with its label (1= greater/equal to 3, 0= under 3)

# %%
# Function to create model features
# for each review, records which uniqeue words out of the whole text body are present
def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

# %%
# Apply function to data
featuresets = [(find_features(text), LABEL) for (text, LABEL) in labtext]
len(featuresets)
# Out:
# 23486

# %% [raw]
# import csv
# with open("test.csv",'w') as resultFile:
#     wr = csv.writer(resultFile)
#     wr.writerow(featuresets)
# # Write model data to CSV for later use

# %%
print(type(featuresets))
# Out:
# <class 'list'>

# %%
training_set = featuresets[:15000]
testing_set = featuresets[15000:]

# %% [markdown]
# ## Naive Bayes

# %%
# %%time
# %%memit
classifier = nltk.NaiveBayesClassifier.train(training_set) # Very scalable algorithm
# Posterior = prior_occurence * likelihood / evidence
# Out:
# peak memory: 3649.20 MiB, increment: 1.00 MiB
# Wall time: 39.6 s

# %%
print("Classifier accuracy percent:",(nltk.classify.accuracy(classifier, testing_set))*100)
print(classifier.show_most_informative_features(25))
# Out:
# Classifier accuracy percent: 88.9347160028
# Most Informative Features
#                    worst = True                0 : 1      =     34.5 : 1.0
#                versatile = True                1 : 0      =     28.0 : 1.0
#                massively = True                0 : 1      =     20.6 : 1.0
#                      rag = True                0 : 1      =     20.6 : 1.0
#                     tore = True                0 : 1      =     20.6 : 1.0
#             anticipating = True                0 : 1      =     20.6 : 1.0
#                   poorly = True                0 : 1      =     17.3 : 1.0
#                  dressed = True                1 : 0      =     16.9 : 1.0
#                    clown = True                0 : 1      =     16.4 : 1.0
#                     mess = True                0 : 1      =     16.3 : 1.0
#                  frankly = True                0 : 1      =     15.9 : 1.0
#                     anti = True                0 : 1      =     14.7 : 1.0
#                    squat = True                0 : 1      =     14.7 : 1.0
#                    middl = True                0 : 1      =     14.7 : 1.0
#            consideration = True                0 : 1      =     14.7 : 1.0
#                     isnt = True                0 : 1      =     14.7 : 1.0
#                     dear = True                0 : 1      =     12.4 : 1.0
#                  sandals = True                1 : 0      =     12.2 : 1.0
#           disappointment = True                0 : 1      =     11.4 : 1.0
#                    shame = True                0 : 1      =     11.4 : 1.0
#                    yikes = True                0 : 1      =     11.4 : 1.0
#              compliments = True                1 : 0      =     10.9 : 1.0
#                 secondly = True                0 : 1      =     10.8 : 1.0
#            disappointing = True                0 : 1      =     10.6 : 1.0
#                 enormous = True                0 : 1      =     10.4 : 1.0

# %% [raw]
# import pickle
# classifier_f = open("naivebayes.pickle", "rb")
# classifier = pickle.load(classifier_f)
# classifier_f.close()
#
# import pickle
# save_classifier = open("naivebayes.pickle","wb")
# pickle.dump(classifier, save_classifier)
# save_classifier.close()

# %% [markdown]
# ## Word2Vec

# %%
import gensim
import os
os.chdir(r"D:\My Computer\DATA\Retail")
os.listdir()
# Out:
# D:\WindowsApps\Anaconda\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# ['featuresets.pickle', 'GoogleNews-vectors-negative300.bin.gz']

# %%
# Load Google's pre-trained Word2Vec model.
#model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
data.head()
# Out:
#                      TITLE                                        REVIEW_TEXT  \
# 0                      NaN  absolutely wonderful - silky and sexy and comf...
# 1                      NaN  Love this dress!  It's sooo pretty.  I happene...
# 2  Some major design flaws  I had such high hopes for this dress and reall...
# 3         My Favorite Buy!  I love, love, love this jumpsuit. It's fun, fl...
# 4         Flattering shirt  This shirt is very flattering to all due to th...
#
#                 CLASS_NAME  AGE  RATING  LABEL  polarity_score  neutral_score  \
# 0  INTIMATES - ANTHRO (NA)   33       4      1          0.8932          0.272
# 1   DRESSES - ANTHRO. (NA)   34       5      1          0.9729          0.664
# 2   DRESSES - ANTHRO. (NA)   60       3      1          0.9520          0.784
# 3     PANTS - PETITES (NA)   50       5      1          0.5727          0.340
# 4   BLOUSES - ANTHRO. (NA)   47       5      1          0.9291          0.700
#
#    negative_score  positive_score sentiment  \
# 0           0.000           0.728  POSITIVE
# 1           0.000           0.336  POSITIVE
# 2           0.027           0.190  POSITIVE
# 3           0.226           0.434  POSITIVE
# 4           0.000           0.300  POSITIVE
#
#                                            tokenized
# 0  [absolutely, wonderful, silky, sexy, comfortable]
# 1  [love, dress, sooo, pretty, happened, find, st...
# 2  [high, hopes, dress, really, wanted, work, ini...
# 3  [love, love, love, jumpsuit, fun, flirty, fabu...
# 4  [shirt, flattering, due, adjustable, front, ti...

# %%
# train word2vec on the two sentences
model = gensim.models.Word2Vec(data.text, min_count=1, sg=1, window = 3) # SKIP-GRAM

# %%
# ?gensim.models.Word2Vec
print(model.vocab)

# %%
model.most_similar('Dress')

# %%
bigram_transformer = gensim.models.Phrases(sentences)
model = Word2Vec(bigram_transformer[sentences], size=100, ...)
